# %%
import IPython
import json
# Numpy is a library for working with Arrays
import numpy as np
# SciPy implements many different numerical algorithms
import scipy as sp
# Pandas is good with data tables
import pandas as pd
# Module for plotting
import matplotlib
#BeautifulSoup parses HTML documents (once you get them via requests)
import bs4
# Nltk helps with some natural language tasks, like stemming
import nltk
# Bson is a binary format of json to be stored in databases
import bson
# Mongo is one of common nosql databases 
# it stores/searches json documents natively
import pymongo
print ("IPython version:      %6.6s", IPython.__version__)
# Out:
# IPython version:      %6.6s 6.5.0

# %% [markdown]
# # Task 1
# ## write a program to produce Fibonacci numbers up to 1000000

# %% [markdown]
# # Task 2
# ## write a program to simulate 1000 tosses of a fair coin (use np.random.binomial)
# ## Calculate the mean and standard deviation of that sample

# %% [markdown]
# # Task 3
# ## Produce a scatterplot of y = 0.5*x+e where x has gaussian (0, 5) and e has gaussian (0, 1) distributions
# ### use numpy.random.normal to generate gaussian distribution

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import math
from mpl_toolkits.mplot3d import Axes3D
from numpy.linalg import inv

def mean(values):
    return np.mean(values)

def variance(values, mean):
    return np.var(values)

def covariance(x, mean_x, y, mean_y):
    covar = 0.0
    for i in range(len(x)):
        covar += (x[i] - mean_x) * (y[i] - mean_y)
    return covar

# Model Evaluation - RMSE
def rmse(Y, Y_pred):
    rmse = np.sqrt(sum((Y - Y_pred) ** 2) / len(Y))
    return rmse

# Model Evaluation - R2 Score
def r2_score(Y, Y_pred):
    mean_y = np.mean(Y)
    ss_tot = sum((Y - mean_y) ** 2)
    ss_res = sum((Y - Y_pred) ** 2)
    r2 = 1 - (ss_res / ss_tot)
    return r2

def cost_function(X, Y, B):
    m = len(Y)
    J = np.sum((X.dot(B) - Y) ** 2)/(2 * m)
    return J

def gradient_descent(X, Y, B, alpha, iterations):
    cost_history = [0] * iterations
    m = len(Y)
    
    for iteration in range(iterations):
        # Hypothesis Values
        h = X.dot(B)
        #print(h)
        # Difference b/w Hypothesis and Actual Y
        loss = h - Y
        # Gradient Calculation
        gradient = X.T.dot(loss) / m
        # Changing Values of B using Gradient
        B = B - alpha * gradient
        # New Cost Value
        cost = cost_function(X, Y, B)
        cost_history[iteration] = cost
        
    return B, cost_history

def main():
    auto = pd.read_csv("auto.csv")
    #sns.countplot(x="cylinders", hue="origin", data=autodata)
    #autodata["mpg"].plot.hist()
    #print(autodata.isnull().sum())
    auto.drop('car name', axis=1, inplace=True)
    #auto.drop('origin', axis=1, inplace=True)
    #auto.drop('model year', axis=1, inplace=True)
    #auto.drop('cylinders', axis=1, inplace=True)
    #auto.drop('displacement', axis=1, inplace=True)
    #print(auto.head(5))
    #auto = (auto - np.mean(auto))/np.std(auto)
    #print(autodata.head(5))
          
    cyl = auto['cylinders'].values
    dis = auto['displacement'].values
    horse = auto['horsepower'].values
    weight = auto['weight'].values
    acc = auto['acceleration'].values
    modelyr = auto['model year'].values
    origin = auto['origin'].values
    mpg = auto['mpg'].values
    
    features = {'cyl' : cyl, 'dis' : dis, 'horse' : horse, 'weight' : weight, 'acc' : acc, 'model' : modelyr, 'origin' : origin}
    #for i in features:
        #plt.scatter(features[i], mpg, color='red')
        #plt.title('mpg Vs ' + i, fontsize=14)
        #plt.xlabel(i, fontsize=14)
        #plt.ylabel('mpg', fontsize=14)
        #plt.grid(True)
        #plt.show()

    
    #fig = plt.figure()
    #ax = Axes3D(fig)
    #ax.scatter(cyl, dis, horse, weight, color='#ef1234')
    #plt.show()
    
    m = len(dis)
    x0 = np.ones(m)
    X = np.array([cyl, dis, horse, weight, acc, modelyr, origin]).T
    XT = np.array([cyl, dis, horse, weight, acc, modelyr, origin])
    Y = np.array(mpg)
    XT =X.T
    XTX = XT@X

    inv=np.linalg.pinv(XTX)

    theta=(inv@XT)@Y
    print(theta)
    newB = theta
    
    #newB = []
    #newB = (inv((X.T).dot(X))).dot((X.T).dot(Y))
    #print(newB)
    
  

    # Initial Coefficients
    B = np.array([0, 0, 0, 0, 0, 0, 0])
    
    alpha = 0.00000003
    
    #print(X)
    #print(Y)
    
    #inital_cost = cost_function(X, Y, B)
    #print(inital_cost)
    #newB = []
    
    #newB, cost_history = gradient_descent(X, Y, B, alpha, 1000)

    # New Values of B
    #print(newB)

    # Final Cost of new B
    #print(cost_history[-1])
    
    Y_pred = X.dot(newB)

    print("RMSE " + str(rmse(Y, Y_pred)))
    print("R2 " + str(r2_score(Y, Y_pred)))
    errors = []
    #newB = []
    
    
    for j in features:
        #mean_x, mean_y = mean(features[j]), mean(mpg)
        #var_x, var_y = variance(features[j], mean_x), variance(mpg, mean_y)
        #print(j)
        #print('x stats: mean=%.3f variance=%.3f' % (mean_x, var_x))
        #print('y stats: mean=%.3f variance=%.3f' % (mean_y, var_y))

        #covar = covariance(features[j], mean_x, mpg, mean_y)
        covar = np.cov(features[j], mpg)[0][1]
        #print('Covariance: %.3f' % (covar))
        var = np.var(features[j])
        #print('Variance is %.3f' % (var))
        #newB.append(covar/var)
        #print('\n')
    
    for x in range(0, len(dis)):   
        number = (newB[0] * cyl[x]) + (newB[1] * dis[x]) + (newB[2] * horse[x]) + (newB[3] * weight[x]) + (newB[4] * acc[x]) + (newB[5] * modelyr[x]) + (newB[6] * origin[x])
        e = ((abs(number - mpg[x]))/mpg[x]) * 100
        errors.append(e)
        print("Actual is " + str(mpg[x]))
        print("Estimated is " + str(number))
        print('\n')
    
    #print("Average error " + str(mean(errors)))

    

main()
# Out:
# [-0.705487    0.0218741  -0.03955653 -0.00603227 -0.07961633  0.58361019
#   1.30995361]
# RMSE 3.351978733985696
# R2 0.8150879680355605
# Actual is 18.0
# Estimated is 15.99929887925699
#
#
# Actual is 15.0
# Estimated is 14.455115719754208
#
#
# Actual is 18.0
# Estimated is 15.93859416105984
#
#
# Actual is 16.0
# Estimated is 15.57083727491549
#
#
# Actual is 17.0
# Estimated is 15.94556250949412
#
#
# Actual is 15.0
# Estimated is 11.08831731318632
#
#
# Actual is 14.0
# Estimated is 10.766123000908628
#
#
# Actual is 14.0
# Estimated is 10.950831790832417
#
#
# Actual is 14.0
# Estimated is 10.082306934179865
#
#
# Actual is 15.0
# Estimated is 13.632949012409952
#
#
# Actual is 15.0
# Estimated is 15.88279796647467
#
#
# Actual is 14.0
# Estimated is 15.219525257940116
#
#
# Actual is 15.0
# Estimated is 15.891206753650156
#
#
# Actual is 14.0
# Estimated is 18.159517077305793
#
#
# Actual is 24.0
# Estimated is 25.17173874397535
#
#
# Actual is 22.0
# ...
